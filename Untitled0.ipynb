# %%
# Home Work
# student : Lachehebi abdelbaki 1 Master ai
# Projet 1 : Segmentation clientèle

# ================================
# Importation des librairies
# ================================

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import kagglehub


# ================================
# Chargement du dataset depuis Kaggle
# ================================
# جبنا بيانات الزبائن من موقع Kaggle

path = kagglehub.dataset_download(
    "abdallahwagih/mall-customers-segmentation"
)

print("Path to dataset files:", path)


# ================================
# Lecture du fichier CSV
# ================================

df = pd.read_csv(path + "/Mall_Customers.csv")

# عرض أول 5 زبائن
df.head()


# ================================
# Exploration des données
# ================================

# عدد الزبائن وعدد الأعمدة
df.shape

# أسماء الأعمدة
df.columns
# ['CustomerID', 'Genre', 'Age', 'Annual Income (k$)', 'Spending Score (1-100)']

# نوع البيانات في كل عمود
df.info()

# إحصائيات عامة (متوسط، أصغر وأكبر قيمة...)
df.describe()

# ================================
# Visualisation بسيطة لفهم البيانات
# ================================

sns.scatterplot(
    x=df["Annual Income (k$)"],
    y=df["Spending Score (1-100)"]
)
plt.title("Income vs Spending Score")
plt.show()


# ================================
# Préparation des données pour le clustering
# ================================

# نختار الأعمدة المهمة فقط
X = df[["Age", "Annual Income (k$)", "Spending Score (1-100)"]]

# Normalisation
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)


# ================================
# Clustering avec K-Means
# ================================

kmeans = KMeans(n_clusters=5, random_state=42)
df["Cluster"] = kmeans.fit_predict(X_scaled)


# ================================
# Visualisation des clusters
# ================================

sns.scatterplot(
    x=df["Annual Income (k$)"],
    y=df["Spending Score (1-100)"],
    hue=df["Cluster"],
    palette="tab10"
)

plt.title("Segmentation des clients avec K-Means")
plt.show()

# Interprétation des résultats (Markdown)

# Cluster 0: دخل عالي وصرف عالي → زبائن VIP

# Cluster 1: دخل عالي وصرف ضعيف → عروض خاصة لتحفيزهم

# Cluster 2: دخل ضعيف → تخفيضات وأسعار منخفضة

# Clusters الأخرى: زبائن متوسطين حسب الدخل والصرف





print("# ================= Project Two =====================")





# Project 2: Détection de fraude






# ================================
#  Télécharger et charger le dataset
# ================================

path_fraud = kagglehub.dataset_download(
    "mlg-ulb/creditcardfraud"
)

print("Path fraud dataset:", path_fraud)


df_fraud = pd.read_csv(path_fraud + "/creditcard.csv")
df_fraud.head()
# كل سطر = عملية دفع
# الأعمدة V1..V28 = خصائص (مشفّرة)
# Class = الهدف





# ================================
#  Exploration des données
# ================================


# عدد العمليات وعدد الأعمدة
print(df_fraud.shape)

# أسماء الأعمدة
print(df_fraud.columns)

# معلومات الأعمدة وأنواع البيانات
df_fraud.info()

# إحصائيات عامة
df_fraud.describe()


# ================================
#  Analyse de la distribution des classes
# ================================


# عدد العمليات العادية vs الاحتيالية
print(df_fraud["Class"].value_counts())

# رسم بياني للتوزيع
sns.countplot(x="Class", data=df_fraud)
plt.title("Distribution des classes")
plt.show()



# ================================⃣
# Préparation des données
# ================================


# فصل المتغيرات عن الهدف
X = df_fraud.drop("Class", axis=1)
y = df_fraud["Class"]

# تقسيم البيانات Train / Test
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

# Normalisation
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)



# ================================⃣
# ⃣ Modèle 1: Logistic Regression
# ================================

lr = LogisticRegression(max_iter=1000)
lr.fit(X_train_scaled, y_train)

y_pred_lr = lr.predict(X_test_scaled)

print("Classification Report (Logistic Regression):")
print(classification_report(y_test, y_pred_lr))

# Confusion Matrix
cm_lr = confusion_matrix(y_test, y_pred_lr)
sns.heatmap(cm_lr, annot=True, fmt="d")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix - Logistic Regression")
plt.show()






# ================================⃣
#⃣ Modèle 2: Random Forest
# ================================


rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train_scaled, y_train)

y_pred_rf = rf.predict(X_test_scaled)

print("Classification Report (Random Forest):")
print(classification_report(y_test, y_pred_rf))

# Confusion Matrix
cm_rf = confusion_matrix(y_test, y_pred_rf)
sns.heatmap(cm_rf, annot=True, fmt="d")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix - Random Forest")
plt.show()



# Interprétation (Markdown)

# Dataset غير متوازن → عمليات الاحتيال قليلة

# Logistic Regression يعطي نتائج معقولة

# Random Forest أفضل خاصة في كشف الاحتيال (Recall أعلى)

# يمكن تحسين النتائج لاحقًا باستعمال AutoML أو تقنيات موازنة البيانات





print("# ================= AUTO  Ml  =====================")

# Application d’AutoML sur Projet 2


from tpot import TPOTClassifier

# إنشاء موديل TPOT
tpot = TPOTClassifier(
    generations=5,
    population_size=20,
    verbosity=2,
    random_state=42,
    scoring='f1'
)

tpot.fit(X_train_scaled, y_train)
y_pred_tpot = tpot.predict(X_test_scaled)


print("Classification Report (TPOT AutoML):")
print(classification_report(y_test, y_pred_tpot))

cm_tpot = confusion_matrix(y_test, y_pred_tpot)
sns.heatmap(cm_tpot, annot=True, fmt="d")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix - TPOT AutoML")
plt.show()


tpot.export('tpot_best_pipeline.py')
# Out:
# Using Colab cache for faster access to the 'mall-customers-segmentation' dataset.
# Path to dataset files: /kaggle/input/mall-customers-segmentation
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Genre                   200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB
# # ================= Project Two =====================
# Using Colab cache for faster access to the 'creditcardfraud' dataset.
# Path fraud dataset: /kaggle/input/creditcardfraud
# (284807, 31)
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
# ...
